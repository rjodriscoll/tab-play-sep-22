# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

from numpy.fft import rfft, irfft, rfftfreq
from scipy import pi, signal, fftpack

# %%
df = pd.read_csv("data/train.csv")
df = df.groupby(["date"]).sum()
df["date"] = df.index
df = df.reset_index(drop=True)[["date", "num_sold"]]
df.head()
# Out:
#          date  num_sold
# 0  2017-01-01     15352
# 1  2017-01-02     11578
# 2  2017-01-03     10884
# 3  2017-01-04     10445
# 4  2017-01-05      9795

# %%
sns.lineplot(data=df, x="date", y="num_sold")
# Out:
# <AxesSubplot:xlabel='date', ylabel='num_sold'>
